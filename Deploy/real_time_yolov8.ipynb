# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r"C:\Users\Lam\Downloads\yolo_7.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    results = model.predict(frame,conf=0.4, save=True, save_txt=True)
    
    boxes_data = results[0].boxes.xyxy.cpu().numpy() if results[0].boxes is not None else []
    for box in boxes_data:
        x, y, w, h = map(int, box)
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)


    cv2.imshow('YOLOv8 Object Detection', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Fire, 229.8ms
# Speed: 1.0ms preprocess, 229.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 223.3ms
# Speed: 2.0ms preprocess, 223.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 205.4ms
# Speed: 1.5ms preprocess, 205.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 216.6ms
# Speed: 1.0ms preprocess, 216.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 225.4ms
# Speed: 4.0ms preprocess, 225.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 213.1ms
# Speed: 2.0ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 204.9ms
# Speed: 1.0ms preprocess, 204.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 211.0ms
# Speed: 1.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 223.2ms
# Speed: 1.0ms preprocess, 223.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 216.7ms
# Speed: 2.0ms preprocess, 216.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 219.9ms
# Speed: 1.5ms preprocess, 219.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 216.5ms
# Speed: 1.1ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 225.8ms
# Speed: 1.1ms preprocess, 225.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 217.2ms
# Speed: 1.0ms preprocess, 217.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 207.8ms
# Speed: 1.0ms preprocess, 207.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 225.6ms
# Speed: 1.1ms preprocess, 225.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 219.7ms
# Speed: 1.0ms preprocess, 219.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 233.1ms
# Speed: 1.0ms preprocess, 233.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 217.3ms
# Speed: 1.0ms preprocess, 217.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 218.2ms
# Speed: 1.0ms preprocess, 218.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 217.7ms
# Speed: 2.0ms preprocess, 217.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 227.1ms
# Speed: 1.5ms preprocess, 227.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 220.5ms
# Speed: 1.0ms preprocess, 220.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 4 Fires, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 4 Fires, 213.0ms
# Speed: 1.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 5 Fires, 208.4ms
# Speed: 1.0ms preprocess, 208.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 214.8ms
# Speed: 1.0ms preprocess, 214.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 216.8ms
# Speed: 1.1ms preprocess, 216.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 212.5ms
# Speed: 1.0ms preprocess, 212.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 218.5ms
# Speed: 1.0ms preprocess, 218.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 208.5ms
# Speed: 1.0ms preprocess, 208.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 210.2ms
# Speed: 2.5ms preprocess, 210.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 226.3ms
# Speed: 1.0ms preprocess, 226.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 222.3ms
# Speed: 2.3ms preprocess, 222.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 226.1ms
# Speed: 1.0ms preprocess, 226.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 218.4ms
# Speed: 2.0ms preprocess, 218.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 220.0ms
# Speed: 1.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 218.1ms
# Speed: 1.0ms preprocess, 218.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 219.2ms
# Speed: 1.0ms preprocess, 219.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 219.7ms
# Speed: 1.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 215.4ms
# Speed: 2.0ms preprocess, 215.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 209.4ms
# Speed: 1.0ms preprocess, 209.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 3 Fires, 217.6ms
# Speed: 1.0ms preprocess, 217.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 217.3ms
# Speed: 1.0ms preprocess, 217.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 214.1ms
# Speed: 1.0ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 206.9ms
# Speed: 2.0ms preprocess, 206.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 202.1ms
# Speed: 1.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 2 Fires, 210.6ms
# Speed: 1.0ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 221.8ms
# Speed: 2.0ms preprocess, 221.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 215.7ms
# Speed: 1.0ms preprocess, 215.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 230.3ms
# Speed: 1.1ms preprocess, 230.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 232.1ms
# Speed: 1.0ms preprocess, 232.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 225.3ms
# Speed: 2.0ms preprocess, 225.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 1 Fire, 238.8ms
# Speed: 2.0ms preprocess, 238.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
#
# 0: 480x640 (no detections), 223.5ms
# Speed: 1.0ms preprocess, 223.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
